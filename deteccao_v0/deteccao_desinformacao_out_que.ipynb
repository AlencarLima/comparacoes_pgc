# %%
import openpyxl
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.util import bigrams
import csv
import re
from itertools import islice
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk import word_tokenize, bigrams
from nltk.corpus import stopwords
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
nltk.download('punkt')
# Download das stopwords em português se ainda não estiverem baixadas
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\carlo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\carlo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\carlo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
caminho_termos_chave = './data_input/termos_chaves/queTextos.xlsx'
caminho_cluster_0 = './data_input/clusters/Oct_2022_cluster_0.csv'
caminho_cluster_1 = './data_input/clusters/Oct_2022_cluster_1.csv'
textos_encontrados_cluster_0 = './resultados/cluster_0/1_bigrama_queTextos_cluster_0.xlsx'
textos_encontrados_cluster_1 = './resultados/cluster_1/1_bigrama_queTextos_cluster_1.xlsx'

# %%
def procurar_e_imprimir(textos, termos):
    nltk.download('punkt')
    resultados = {termo: [] for termo in termos}
    textos_utilizados = set()

    for termo in termos:
        bigramas_termo = list(bigrams(termo.lower().split()))
        textos_encontrados = 0

        for texto in textos:
            if texto['text'] in textos_utilizados:
                continue

            texto_lower = texto['text'].lower()
            palavras_texto = word_tokenize(texto_lower)
            bigramas_texto = list(bigrams(palavras_texto))
            count = sum(1 for bigrama in bigramas_termo if bigrama in bigramas_texto)

            if count >= 1:  # Verifica se pelo menos 1 bigramas do termo estão no texto
                texto['correspondencia'] = count
                resultados[termo].append(texto)
                textos_utilizados.add(texto['text'])
                textos_encontrados += 1

    return resultados

# %%
def main():
    # Carregar termos da coluna da planilha .xlsx
    # wb = openpyxl.load_workbook('../PGC_fact_check/resultados/arquivo_limpo.xlsx')
    wb = openpyxl.load_workbook(caminho_termos_chave)
    planilha = wb['Sheet1']

    # Extrair termos-chave da coluna 'Termos_chave' (coluna F)
    termos = [celula.value for celula in planilha['F'] if celula.value]

    # Carregar textos da coluna 'text' do arquivo CSV e remover duplicatas
    with open(caminho_cluster_0, 'r', encoding='utf-8') as arquivo:
        leitor_csv = csv.DictReader(arquivo)
        textos = [{key: row[key] for key in row} for row in leitor_csv if row['text']]

    # Procurar e imprimir textos relevantes para cada termo
    resultados = procurar_e_imprimir(textos, termos)

    # Criar lista de dicionários para os resultados
    lista_resultados = []
    for termo, textos_relevantes in resultados.items():
        for texto in textos_relevantes:
            texto['termo'] = termo
            lista_resultados.append(texto)

    # Criar DataFrame a partir da lista de dicionários
    df_resultados = pd.DataFrame(lista_resultados)

    # Salvar os resultados em um arquivo Excel
    df_resultados.to_excel(textos_encontrados_cluster_0, index=False)

    print('Resultados salvos com sucesso.')

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\carlo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Resultados salvos com sucesso.

# %%
def main():
    # Carregar termos da coluna da planilha .xlsx
    # wb = openpyxl.load_workbook('../PGC_fact_check/resultados/arquivo_limpo.xlsx')
    wb = openpyxl.load_workbook(caminho_termos_chave)
    planilha = wb['Sheet1']

    # Extrair termos-chave da coluna 'Termos_chave' (coluna F)
    termos = [celula.value for celula in planilha['F'] if celula.value]

    # Carregar textos da coluna 'text' do arquivo CSV e remover duplicatas
    with open(caminho_cluster_1, 'r', encoding='utf-8') as arquivo:
        leitor_csv = csv.DictReader(arquivo)
        textos = [{key: row[key] for key in row} for row in leitor_csv if row['text']]

    # Procurar e imprimir textos relevantes para cada termo
    resultados = procurar_e_imprimir(textos, termos)

    # Criar lista de dicionários para os resultados
    lista_resultados = []
    for termo, textos_relevantes in resultados.items():
        for texto in textos_relevantes:
            texto['termo'] = termo
            lista_resultados.append(texto)

    # Criar DataFrame a partir da lista de dicionários
    df_resultados = pd.DataFrame(lista_resultados)

    # Salvar os resultados em um arquivo Excel
    df_resultados.to_excel(textos_encontrados_cluster_1, index=False)

    print('Resultados salvos com sucesso.')

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\carlo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Resultados salvos com sucesso.

# %%
def contar_termos_com_desinformacao(df):
    # Filtrar apenas os textos com desinformação
    df_desi_texts = df[df['desinformacao'].str.lower() == 'sim']
    
    # Contar a frequência dos termos nos textos com desinformação
    termo_counts = df_desi_texts['termo'].value_counts()
    
    return termo_counts

# %%
def load_excel(file_path, sheet_name):
    labeled_data = pd.read_excel(file_path, sheet_name=sheet_name)
    return labeled_data

# Função para carregar os dados não rotulados de um arquivo CSV
def load_csv(file_path):
    unlabeled_data = pd.read_csv(file_path)
    return unlabeled_data

# Função para rotular os textos não rotulados usando similaridade de cosseno
def label_unlabeled_data(unlabeled_data, labeled_data, vectorizer, threshold=0.9):
    X_unlabeled_tfidf = vectorizer.transform(unlabeled_data['text'])
    X_labeled_tfidf = vectorizer.transform(labeled_data['text'])
    labels = []
    similarities = []
    similar_terms = []

    for i in range(X_unlabeled_tfidf.shape[0]):
        similarity_scores = cosine_similarity(X_unlabeled_tfidf[i], X_labeled_tfidf)
        max_similarity = similarity_scores.max()
        similarities.append(max_similarity)

        if max_similarity > threshold:
            similar_doc_index = similarity_scores.argmax()
            labels.append(labeled_data.iloc[similar_doc_index]['desinformacao'])
            similar_terms.append(labeled_data.iloc[similar_doc_index]['Termos_chave'])  # Pega o termo associado
        else:
            labels.append(-1)
            similar_terms.append(None)

    return labels, similarities, similar_terms

# %%
caminho_cluster_0_rotulado = './resultados/rotulado/Oct_2022_cluster_0_labeled_que.xlsx'
caminho_cluster_1_rotulado = './resultados/rotulado/Oct_2022_cluster_1_labeled_que.xlsx'

# %%
# Carregar os dados rotulados e não rotulados
labeled_data = load_excel('./data_input/texto_encontrados_out_2022.xlsx', 'Cluster_1')
unlabeled_data = load_excel(textos_encontrados_cluster_1, 'Sheet1')

# Vetorizar os textos rotulados com TF-IDF
vectorizer = TfidfVectorizer().fit(labeled_data['text'])

# Rotular os textos não rotulados e obter as similaridades e termos
labels, similarities, similar_terms = label_unlabeled_data(unlabeled_data, labeled_data, vectorizer)

# Adicionar os rótulos, similaridades e termos ao DataFrame não rotulado
unlabeled_data['desinformacao'] = labels
unlabeled_data['similaridade'] = similarities
unlabeled_data['termo_similar'] = similar_terms

# Salvar todos os dados rotulados e não rotulados em um novo Excel
output_path = caminho_cluster_1_rotulado
with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
    unlabeled_data.to_excel(writer, sheet_name='Rotulados', index=False)

# Filtrar os dados que não foram rotulados (-1)
unlabeled_unlabeled = unlabeled_data[unlabeled_data['desinformacao'] == -1]

# Salvar os dados não rotulados em uma aba separada
with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
    unlabeled_data.to_excel(writer, sheet_name='Rotulados', index=False)
    unlabeled_unlabeled.to_excel(writer, sheet_name='Não Rotulados', index=False)

print(f"Dados salvos em: {output_path}")
# Out:
# Dados salvos em: ./resultados/rotulado/Oct_2022_cluster_1_labeled_que.xlsx

# %%
# Carregar os dados rotulados e não rotulados
labeled_data = load_excel('data_input/texto_encontrados_out_2022.xlsx', 'Cluster_0')
unlabeled_data = load_excel(textos_encontrados_cluster_0, 'Sheet1')

# Vetorizar os textos rotulados com TF-IDF
vectorizer = TfidfVectorizer().fit(labeled_data['text'])

# Rotular os textos não rotulados e obter as similaridades e termos
labels, similarities, similar_terms = label_unlabeled_data(unlabeled_data, labeled_data, vectorizer)

# Adicionar os rótulos, similaridades e termos ao DataFrame não rotulado
unlabeled_data['desinformacao'] = labels
unlabeled_data['similaridade'] = similarities
unlabeled_data['termo_similar'] = similar_terms

# Salvar todos os dados rotulados e não rotulados em um novo Excel
output_path = caminho_cluster_0_rotulado
with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
    unlabeled_data.to_excel(writer, sheet_name='Rotulados', index=False)

# Filtrar os dados que não foram rotulados (-1)
unlabeled_unlabeled = unlabeled_data[unlabeled_data['desinformacao'] == -1]

# Salvar os dados não rotulados em uma aba separada
with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
    unlabeled_data.to_excel(writer, sheet_name='Rotulados', index=False)
    unlabeled_unlabeled.to_excel(writer, sheet_name='Não Rotulados', index=False)

print(f"Dados salvos em: {output_path}")
# Out:
# Dados salvos em: ./resultados/rotulado/Oct_2022_cluster_0_labeled_que.xlsx

# %%
def main():
    # Carregar dados de desinformação
    # df_desi = pd.read_excel('./resultados/rotulado/Oct_2022_cluster_0_labeled.xlsx', sheet_name='Rotulados')
    df_desi = pd.read_excel(caminho_cluster_0_rotulado, sheet_name='Rotulados')
    
    # Contar os termos que possuem "sim" na coluna desinformacao
    termo_counts = contar_termos_com_desinformacao(df_desi)
    
    # Ordenar e selecionar os top 5 termos mais frequentes
    top_5_termos = termo_counts.head(5)
    
    # Exibir os 5 termos mais frequentes com desinformação
    for termo, count in top_5_termos.items():
        print(f"Termo: {termo}, Quantidade de Desinformação: {count}")

if __name__ == "__main__":
    main()
# Out:
# Termo: ['o tse (tribunal superior eleitoral) não testou a segurança das urnas para as eleições de 2022', 'as vulnerabilidades encontradas no sistema em 2012 ainda não foram corrigidas,', 'diego aranha, professor assistente de segurança de sistemas na universidade de aarhus, na dinamarca, anuncia o projeto você fiscal,', 'acumulam mais de 2', 'não é possível estimar o alcance', 'o especialista em segurança digital diego aranha apresenta o projeto você fiscal circula nas redes fora de contexto para sugerir', 'há vulnerabilidades nas urnas', 'o tse (tribunal superior eleitoral) não realizou testes públicos de verificação de segurança para o pleito de 2022', 'a gravação foi feita naquela época: a expressão “eleições 2014” aparece aos 35’’ (veja abaixo)', 'à época atuava', 'encontrou uma vulnerabilidade no sigilo do voto garantido pelo rdv (registro digital do voto), espécie de tabela', 'registra aleatoriamente os votos computados pelos eleitores', 'as vulnerabilidades foram corrigidas, o', 'detalha melhorias no sistema', 'sugerem as postagens, foi feito um teste para o pleito de 2022, entre os dias 22', '“', 'a fase de transmissão/totalização dos resultados é plenamente auditável pela sociedade', 'envolvem o software de votação continuam com limitações importantes de transparência”', 'faz a leitura do qr code disponível no boletim impresso pela urna da seção eleitoral', 'ataca a justiça eleitoral', 'o projeto havia sido desativado'], Quantidade de Desinformação: 480
# Termo: ['recorreram à desinformação em mais de uma ocasião', 'recorreram à desinformação em mais de uma ocasião', 'já teve dois mandatos de oito anos cada, perdeu a reeleição em 2018', 'já teve dois mandatos de oito anos cada, perdeu a reeleição em 2018', 'até o momento deixou 686,3 mil mortos, foram os assuntos mais checados desses políticos', 'o relatório final da cpi da covid, realizada em 2021, trouxe o nome de 26 parlamentares', 'teriam divulgado desinformação sobre a pandemia', 'já foram checados pela lupa,', 'até o momento deixou 686,3 mil mortos , foram os assuntos mais checados desses políticos', 'o relatório final da cpi da covid, realizada em 2021, trouxe o nome de 26 parlamentares', 'teriam divulgado desinformação sobre a pandemia', 'já foram checados pela lupa ,', 'ocuparam cargo de ministro no governo de jair bolsonaro (pl)', 'escolas da holanda ensinavam os pais a masturbarem os filhos', 'ocuparam cargo de ministro no governo de jair bolsonaro (pl)', 'escolas da holanda ensinavam os pais a masturbarem os filhos', 'especialistas na holanda ensinam aos pais', 'as meninas vítimas de abuso sexual na ilha de marajó (pa) são abusadas “', 'especialistas na holanda ensinam aos pais', 'as meninas vítimas de abuso sexual na ilha de marajó (pa) são abusadas “', 'cartilha do governo lula ensinava a usar crack', 'cartilha do governo lula ensinava a usar crack', 'ocupava no governo bolsonaro', 'ocupava no governo bolsonaro', 'o vírus sars-cov-2, causador da covid-19, teria sido patenteado antes da pandemia,', 'as sequelas causadas por vacinas contra a doença não seriam notificadas', 'o vírus sars-cov-2, causador da covid-19, teria sido patenteado antes da pandemia,', 'as sequelas causadas por vacinas contra a doença não seriam notificadas', 'afirmava, falsamente,', 'a proteína spike criada pelas vacinas de mrna', 'já foi desmentida inúmeras vezes', 'ensinava as pessoas um “truque” para não usar máscaras', 'afirmava, falsamente,', 'a proteína spike criada pelas vacinas de mrna', 'já foi desmentida inúmeras vezes', 'ensinava as pessoas um “truque” para não usar máscaras', 'elegeram joe biden', 'apontaria mais votos no ex-presidente donald trump', 'seu adversário', 'a empresa dominion, responsável por produzir sistemas eletrônicos de votação, teria excluído da apuração 2,7 milhões de votos para trump', 'elegeram joe biden', 'apontaria mais votos no ex-presidente donald trump', 'seu adversário', 'a empresa dominion, responsável por produzir sistemas eletrônicos de votação, teria excluído da apuração 2,7 milhões de votos para trump', 'os portais de notícias não teriam repercutido a fala do ex-presidente lula (pt) sobre o covid', 'os portais de notícias não teriam repercutido a fala do ex-presidente lula (pt) sobre o covid', 'tem', 'indicaria', 'o inquérito “abre precedente para grave retrocesso no império da lei', 'tem', 'indicaria', 'o inquérito “abre precedente para grave retrocesso no império da lei', 'a primeira bateria de nióbio do mundo era fruto de um trabalho do ministério da ciência', 'um projeto do deputado orlando silva (pcdob) na câmara legalizava o casamento entre pais', 'não é verdade', 'a primeira bateria de nióbio do mundo era fruto de um trabalho do ministério da ciência', 'um projeto do deputado orlando silva (pcdob) na câmara legalizava o casamento entre pais', 'não é verdade', 'usou o plenário da câmara federal para propagar informações falsas sobre a pandemia,', 'usou o plenário da câmara federal para propagar informações falsas sobre a pandemia,', '“', 'existe tratamento precoce [contra o novo coronavírus]', 'muitos não querem adotá-lo”', 'profilaxia medicamentosa previna', '“', 'existe tratamento precoce [contra o novo coronavírus]', 'muitos não querem adotá-lo”', 'profilaxia medicamentosa previna', 'apagar as mensagens', 'apagar as mensagens', 'usou o plenário para disseminar informação falsa', 'usou o plenário para disseminar informação falsa', 'o “kit covid” levaria a suposta uma taxa de sobrevivência pró ...
# Termo: ['escapam às metodologias de checagem', 'escapam às metodologias de checagem', 'recebeu uma ameaça de morte', 'tanto ódio aos cristãos?", associando as ameaças', 'recebeu a uma suposta perseguição religiosa', 'recebeu uma ameaça de morte', 'tanto ódio aos cristãos?", associando as ameaças', 'recebeu a uma suposta perseguição religiosa', 'monitora conteúdos publicados em cerca de 400 canais', 'a “perseguição religiosa é a narrativa em destaque na extrema direita evangélica, principalmente pela repercussão dos casos de damares alves', 'viralizaram na última semana”', 'alguns termos estão sendo estrategicamente mencionados com maior frequência, entre eles “ditadura, fascistas, odiosos', 'monitora conteúdos publicados em cerca de 400 canais', 'a “perseguição religiosa é a narrativa em destaque na extrema direita evangélica, principalmente pela repercussão dos casos de damares alves', 'viralizaram na última semana”', 'alguns termos estão sendo estrategicamente mencionados com maior frequência, entre eles “ditadura, fascistas, odiosos', 'colocam em xeque a legitimidade do sistema eleitoral brasileiro —', 'achava “estranho” o fato de ele, o governador romeu zema (novo-mg)', 'colocam em xeque a legitimidade do sistema eleitoral brasileiro —', 'achava “estranho” o fato de ele, o governador romeu zema (novo-mg)', 'as declarações com informações distorcidas por esses políticos,', 'já ocupavam papéis de influenciadores', 'teóricos chamam de “zona cinzenta” da desinformação', 'fica difícil cravar o', 'é verdade', 'as declarações com informações distorcidas por esses políticos,', 'já ocupavam papéis de influenciadores', 'teóricos chamam de “zona cinzenta” da desinformação', 'fica difícil cravar o', 'é verdade', 'esses conteúdos são trabalhados a partir da perspectiva de uma disputa de narrativa', 'esses conteúdos são trabalhados a partir da perspectiva de uma disputa de narrativa', 'vão encaixando esses discursos', 'conseguem burlar, de certa forma, os critérios', 'essas pessoas desenvolveram para assegurar a confiabilidade da informação', 'consomem”, afirma massaro', 'vão encaixando esses discursos', 'conseguem burlar, de certa forma, os critérios', 'essas pessoas desenvolveram para assegurar a confiabilidade da informação', 'consomem”, afirma massaro', 'ainda não era parlamentar – damares alves –', 'ainda não era parlamentar – damares alves –', 'a elegeram, ela passou a fazer campanha para bolsonaro', 'a elegeram, ela passou a fazer campanha para bolsonaro', '“o inferno', 'havia imagens de crianças de 4 anos cruzando as fronteiras com os dentes arrancados “para não morderem na hora do sexo oral”', '“o inferno', 'havia imagens de crianças de 4 anos cruzando as fronteiras com os dentes arrancados “para não morderem na hora do sexo oral”', 'os documentos', 'supostamente comprovariam a declaração da política não representam nenhuma prova concreta', 'cita uma cena idêntica à descrita pela ex-ministra', 'os documentos', 'supostamente comprovariam a declaração da política não representam nenhuma prova concreta', 'cita uma cena idêntica à descrita pela ex-ministra', 'especialistas na holanda ensinam aos pais', 'meninas vítimas de abuso sexual na ilha de marajó (pa) são abusadas “', 'especialistas na holanda ensinam aos pais', 'meninas vítimas de abuso sexual na ilha de marajó (pa) são abusadas “', 'a disputa de narrativas entre eles foi reprovada pela “extrema direita evangélica”', 'seria ‘capaz de tudo pelo poder’”', 'a disputa de narrativas entre eles foi reprovada pela “extrema direita evangélica”', 'seria ‘capaz de tudo pelo poder’”', 'são acusados de disseminar informações falsas', 'eles discordam eles chamam de ‘fakenews’', 'são acusados de disseminar informações falsas', 'eles discordam eles chamam de ‘fakenews’', 'a ex-ministra de bolsonaro aparece denunciando “crueldades contra crianças”', '“estupros de recém nascidos', 'a ex-ministra de bolsonaro aparece denunciando “crueldades contra crianças”', '“estupros de recém nascidos', 'i ...
# Termo: ['tivemos acesso aponta para uma suposta pegadinha da justiça eleitoral', 'circulam online: versão 1: importante ao votar prestar atenção ao digitar vai aparecer escrito confira confira seu voto', 'aguardar a mensagem confira, parar de piscar para poder confirmar,', 'aponta para a', 'informações falsas sobre “coisas”', 'anulam votos circulam por aí', 'votar', 'votar em daniel silveira anularia tudo', 'circulam online são vagos, alarmistas, têm erros de português', 'confirme a informação', 'a tela em questão não tem qualquer relação com anulação', 'acontece', 'dura 1', 'fizemos no site do tse (faça aqui, é bem divertido), a urna deu um som de erro', 'aponta', 'apertar “confirma” durante a tela “confira seu voto” anula o voto', 'está circulando com força na internet'], Quantidade de Desinformação: 168
# Termo: ['isso', 'permite o voto para presidente a pessoas', 'estão longe dos seus domicílios eleitorais,', 'só', 'seu título foi registrado', 'viralizou nas redes sociais engana ao dizer', 'é um indício de fraude o número maior de eleitores aptos a escolher o presidente da república em relação aos demais cargos em uma seção de macapá', 'houve registro de votos em trânsito, procedimento', 'permite ao eleitor votar em um município', 'é a citada no vídeo, 125 eleitores estavam aptos a votar em todos os cargos', 'seu título foi registrado, ele pode votar para todos os cargos', 'um homem questiona a diferença de votos para presidente', 'a divergência na seção citada indica “quantas pessoas de outros estados brasileiros', 'mostram', 'a seção 100 da zona eleitoral 276 de uberaba (mg) possuía 348 eleitores aptos para votar em todos os candidatos, dos quais compareceram 263,'], Quantidade de Desinformação: 122

# %%
def main():
    # Carregar dados de desinformação
    df_desi = pd.read_excel(caminho_cluster_1_rotulado, sheet_name='Rotulados')
    
    # Imprimir textos com maior correspondência (coluna correspondencia)
    top_textos = df_desi.sort_values(by='correspondencia', ascending=False).head(5)
    print("\nTextos com Maior Correspondência:")
    for idx, row in top_textos.iterrows():
        print(f"Texto: {row['text']}, Correspondência: {row['correspondencia']}")
        
        # Calcular a média da correspondência dos top textos
    media_correspondencia = top_textos['correspondencia'].mean()
    print(f"\nMédia da Correspondência dos Top Textos: {media_correspondencia}")
    
    # Calcular a média da correspondência de todos os textos
    media_correspondencia = df_desi['correspondencia'].mean()
    print(f"\nMédia da Correspondência de Todos os Textos: {media_correspondencia}")

if __name__ == "__main__":
    main()
# Out:
# Textos com Maior Correspondência:
# Texto: Fiquei sabendo que o @JairBolsonaro foi convencido pelos seus irmãos maçons a exigir o voto impresso pra que o comprovante, com o nome de cada eleitor, fosse queimado em fogueira de ritual ocultista pagão nas lojas da Maçonaria.
#
# #JairNãoÉCristão #BolsonaroMaçom, Correspondência: 9
# Texto: @Ticostacruz @Ticostacruz eles estão praticando voto de vmcabresto adoidado. Eu mesma fiquei sabendo de um caso de assédiopor empregador pela esposa de um empregado, mas não falei nada pra não expô-la. Vamos fazer muita campanha contra a compra de votos. Não à toa queriam voto impresso, Correspondência: 8
# Texto: a gente já fica assim votando em urna eletrônica com o resultando saindo no mesmo dia imagina só se fizéssemos que nem os australopiteco conhecidos como estadunidenses https://t.co/nePYZhM36L, Correspondência: 7
# Texto: Hoje eu aperto o dedo com o maior prazer na urna eletronica com meu título no bolso e meu diploma de burro no bolso como disse o capetão!!!, Correspondência: 7
# Texto: @LulaOficial @ricardostuckert Gente fiquei apertando 17 e nada de aparecer o mito… essas urnas são fraude!!! Acabei votando no 13 pq fui testar se o 13 daria certo e acabou dando. Precisamos de uma revolução para invalidar essas urnas. Voto Impresso auditável já!!!, Correspondência: 6
#
# Média da Correspondência dos Top Textos: 7.4
#
# Média da Correspondência de Todos os Textos: 1.588613406795225

# %%
def criar_grafico_desinformacao(df_cluster, df_desi, ax, titulo, labels):
    # Filtrar textos únicos no cluster
    df_cluster_unique = df_cluster.drop_duplicates(subset='text')
    
    # Inicializar contadores
    total_textos = df_cluster_unique.shape[0]
    desinformacao_count = 0
    nao_rotulado_count = 0
    
    # Iterar sobre os textos únicos no cluster
    df_merged = df_cluster_unique.merge(df_desi[['text', 'desinformacao']], on='text', how='left')

    df_merged['desinformacao_norm'] = df_merged['desinformacao'].str.strip().str.lower()

    desinformacao_count = (df_merged['desinformacao_norm'] == 'sim').sum()
    nao_rotulado_count = df_merged['desinformacao_norm'].isna().sum()

    # Calcular a porcentagem de desinformação
    total_rotulado = total_textos - nao_rotulado_count
    porcentagem_desinformacao = (desinformacao_count / total_rotulado) * 100 if total_rotulado > 0 else 0
    
    # Criar gráfico de pizza
    sizes = [desinformacao_count, total_rotulado - desinformacao_count, nao_rotulado_count]
    colors = ['#ff9999', '#66b3ff', '#c2c2c2']
    explode = (0.1, 0, 0)  # Explode 1st slice
    
    ax.pie(sizes, explode=explode, labels=labels, colors=colors,
           autopct=lambda p: f'{p:.1f}% ({int(p * total_textos / 100):d})', shadow=True, startangle=140)
    ax.set_title(titulo)

# %%
def main():
    labels = ['Tweets com Desinformação', 'Tweets sem Desinformação', 'Não Rotulado']
    
    # Carregar CSV de textos encontrados e desinformação
    df_cluster_0 = pd.read_csv(caminho_cluster_0)
    df_cluster_1 = pd.read_csv(caminho_cluster_1)
    
    # Carregar dados de desinformação
    df_desi_0 = pd.read_excel(caminho_cluster_0_rotulado, sheet_name='Rotulados')
    df_desi_1 = pd.read_excel(caminho_cluster_1_rotulado, sheet_name='Rotulados')
    
    # Criar figura e eixos para subplots
    fig, axs = plt.subplots(1, 2, figsize=(16, 8))
    
    # Criar gráficos
    criar_grafico_desinformacao(df_cluster_0, df_desi_0, axs[0], 'Gráfico dos retuítes de tweets com desinformação em relação aos retuítes do Cluster 0', labels)
    criar_grafico_desinformacao(df_cluster_1, df_desi_1, axs[1], 'Gráfico dos retuítes de tweets com desinformação em relação aos retuítes do Cluster 1', labels)

    # Mostrar os gráficos
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()

# %%
def main():
    labels = ['Retuítes com Desinformação', 'Retuítes sem Desinformação', 'Não Rotulado']
    # Carregar CSV de textos encontrados e desinformação
    df_cluster_0 = pd.read_csv(caminho_cluster_0)
    df_cluster_1 = pd.read_csv(caminho_cluster_1)
    
    # Carregar dados de desinformação
    df_desi_0 = pd.read_excel(caminho_cluster_0_rotulado, sheet_name='Rotulados')
    df_desi_1 = pd.read_excel(caminho_cluster_1_rotulado, sheet_name='Rotulados')
    
    # Criar figura e eixos para subplots
    fig, axs = plt.subplots(1, 2, figsize=(16, 8))
    
    # Criar gráficos

    criar_grafico_desinformacao(df_cluster_0, df_desi_0, axs[0], 'Gráfico dos retuítes de tweets com desinformação em relação aos retuítes do Cluster 0', labels)
    criar_grafico_desinformacao(df_cluster_1, df_desi_1, axs[1], 'Gráfico dos retuítes de tweets com desinformação em relação aos retuítes do Cluster 1', labels)
    # Mostrar os gráficos
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()

# %%
def criar_grafico_perfis_desinformacao(df_cluster, df_desi):
    # Identificar textos com desinformação (considerando todas as ocorrências)
    df_desi_texts = df_desi[df_desi['desinformacao'].str.lower() == 'sim']
    textos_com_desi = df_desi_texts['text']
    
    # Filtrar apenas os textos com desinformação
    df_desi_texts_cluster = df_cluster[df_cluster['text'].isin(textos_com_desi)]
    
    # Contar a frequência dos perfis em textos com desinformação
    perfil_counts = df_desi_texts_cluster['rtfrom'].value_counts().head(10)
    
    # Calcular porcentagens em relação ao total
    total = perfil_counts.sum()
    porcentagens = (perfil_counts / total) * 100
    
    # Criar gráfico de barras com porcentagens
    plt.figure(figsize=(14, 10))
    bars = perfil_counts.plot(kind='bar', color='red')
    
    # Adicionar rótulos com as porcentagens
    for i, v in enumerate(perfil_counts):
        pct = porcentagens.iloc[i]
        plt.text(i, v + 1, f'{pct:.1f}%', ha='center', fontsize=12)
    
    plt.title('Perfis com Mais Desinformação', fontsize=20)
    plt.xlabel('Perfil', fontsize=16)
    plt.ylabel('Quantidade de Desinformação', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
def main():
    # Carregar CSV de textos encontrados e desinformação (substitua pelo seu caminho real)
    df_cluster = pd.read_csv(caminho_cluster_1)
    
    # Carregar dados de desinformação (substitua pelo seu caminho real)
    df_desi = pd.read_excel(caminho_cluster_1_rotulado, sheet_name='Rotulados')
    
    # Criar gráfico de perfis com mais desinformação
    criar_grafico_perfis_desinformacao(df_cluster, df_desi)

if __name__ == "__main__":
    main()

# %%
def main():
    # Carregar CSV de textos encontrados e desinformação (substitua pelo seu caminho real)
    df_cluster = pd.read_csv(caminho_cluster_0)
    
    # Carregar dados de desinformação (substitua pelo seu caminho real)
    df_desi = pd.read_excel(caminho_cluster_0_rotulado, sheet_name='Rotulados')
    
    # Criar gráfico de perfis com mais desinformação
    criar_grafico_perfis_desinformacao(df_cluster, df_desi)

if __name__ == "__main__":
    main()

# %%
def criar_grafico_perfis_desinformacao_unico(df_cluster, df_desi):
    # Filtrar textos únicos no cluster
    df_cluster_unique = df_cluster.drop_duplicates(subset='text')
    
    # Inicializar lista de textos com desinformação
    textos_com_desi = []
    
    # Adicionar todos os textos da planilha com desinformação 'sim'
    for text in df_cluster_unique['text']:
        if df_desi[(df_desi['text'] == text) & (df_desi['desinformacao'].str.lower() == 'sim')].shape[0] > 0:
            textos_com_desi.append(text)
    
    # Filtrar apenas os textos com desinformação
    df_desi_texts = df_cluster_unique[df_cluster_unique['text'].isin(textos_com_desi)]
    
    # Contar a frequência dos perfis em textos com desinformação
    perfil_counts = df_desi_texts['rtfrom'].value_counts().head(10)
    
    # Calcular porcentagens em relação ao total
    total = perfil_counts.sum()
    porcentagens = (perfil_counts / total) * 100
    
    # Criar gráfico de barras com porcentagens
    plt.figure(figsize=(10, 6))
    bars = perfil_counts.plot(kind='bar', color='red')
    
    # Adicionar rótulos com as porcentagens
    for i, v in enumerate(perfil_counts):
        pct = porcentagens.iloc[i]
        plt.text(i, v + 1, f'{pct:.1f}%', ha='center', fontsize=12)
    
    plt.title('Perfis com Mais Desinformação')
    plt.xlabel('Perfil')
    plt.ylabel('Quantidade de Desinformação')
    plt.show()

# %%
def main():
    # Carregar CSV de textos encontrados e desinformação
    df_cluster = pd.read_csv(caminho_cluster_0)
    
    # Carregar dados de desinformação (substitua pelo seu caminho real)
    df_desi = pd.read_excel(caminho_cluster_0_rotulado, sheet_name='Rotulados')
    
    # Criar gráfico de perfis com mais desinformação
    criar_grafico_perfis_desinformacao_unico(df_cluster, df_desi)

if __name__ == "__main__":
    main()

# %%
def main():
    # Carregar CSV de textos encontrados e desinformação
    df_cluster = pd.read_csv(caminho_cluster_1)
    
    # Carregar dados de desinformação (substitua pelo seu caminho real)
    df_desi = pd.read_excel(caminho_cluster_1_rotulado, sheet_name='Rotulados')
    
    # Criar gráfico de perfis com mais desinformação
    criar_grafico_perfis_desinformacao(df_cluster, df_desi)

if __name__ == "__main__":
    main()

# %%
def extrair_bigramas(textos, termos):
    # Tokenizar os textos em palavras, removendo vírgulas
    textos_tokenizados = [word_tokenize(re.sub(r'[^\w\s]', '', texto.lower())) for texto in textos]
    
    # Lista de stopwords em português
    stop_words = set(stopwords.words('portuguese'))
    
    # Inicializar lista para armazenar bigramas
    bigram_list = []
    
    # Formar bigramas com base nos textos, ignorando stopwords e palavras isoladas
    for texto_tokenizado in textos_tokenizados:
        filtered_texto = [word for word in texto_tokenizado if word not in stop_words and len(word) > 1]
        bigram_list.extend(list(bigrams(filtered_texto)))
    
    # Contar a frequência dos bigramas nos textos
    bigram_counts = Counter()
    for bigram in bigram_list:
        bigram_counts['_'.join(bigram)] += 1
    
    return bigram_counts

def criar_nuvem_de_palavras(bigram_counts):
    if len(bigram_counts) == 0:
        print("Não foram encontrados bigramas nos textos.")
        return
    
    # Obter os 150 bigramas mais frequentes
    top_bigrams = bigram_counts.most_common(150)
    
    # Preparar os dados para a nuvem de palavras
    wordcloud_dict = {bigram.replace(' ', '_'): count for bigram, count in bigram_counts.items()}
    wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='Blues', max_words=150, prefer_horizontal=0.8)
    wordcloud.generate_from_frequencies(wordcloud_dict)
    
    # Definir estilos para os bigramas mais frequentes
    default_style = {
        'font_size': 12,
        'color': 'black',
        'regexp': r'\w[\w\s]*\w'
    }
    
    # Estilos modificados para os top bigramas
    highlighted_style = {
        **default_style,
        'font_size': 30,
        'color': 'blue',
        'font_path': None,
        'bold': True,
        'italic': True,
        'collocations': False
    }
    
    # Atualizar o estilo para os bigramas mais frequentes
    for bigram, _ in top_bigrams:
        wordcloud_dict[bigram.replace(' ', '_')] = 1
    
    # Plotar a nuvem de palavras
    plt.figure(figsize=(12, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Nuvem de Palavras com Bigramas', fontsize=16)
    plt.show()

# %%
def main():
    # Carregar dados de desinformação
    df_desi = pd.read_excel(caminho_cluster_0_rotulado, sheet_name='Rotulados')
    
    # Extrair textos e termos
    textos = df_desi['text'].tolist()
    termos = df_desi['termo'].tolist()
    
    # Extrair bigramas dos textos e contar
    bigram_counts = extrair_bigramas(textos, termos)
    
    # Criar nuvem de palavras dos bigramas encontrados
    criar_nuvem_de_palavras(bigram_counts)

if __name__ == "__main__":
    main()

# %%
def main():
    # Carregar dados de desinformação
    df_desi = pd.read_excel(caminho_cluster_1_rotulado, sheet_name='Rotulados')
    
    # Extrair textos e termos
    textos = df_desi['text'].tolist()
    termos = df_desi['termo'].tolist()
    
    # Extrair bigramas dos textos e contar
    bigram_counts = extrair_bigramas(textos, termos)
    
    # Criar nuvem de palavras dos bigramas encontrados
    criar_nuvem_de_palavras(bigram_counts)

if __name__ == "__main__":
    main()
